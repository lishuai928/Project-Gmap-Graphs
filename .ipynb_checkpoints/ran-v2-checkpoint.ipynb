# %% [markdown]
# 1. get geo index for each county
# 2. write function to get DataFrame of 1. city 2. type 3. page token (optional)
# 3. write function to get 60 places DataFrame
# 4. get multiple city / types
# 5. join them
# 6. profit!

# %%
# Dependencies
import requests
import json
import time
import pandas as pd
import numpy as np
import pprint as pprint
# Google API Key
from config import gkey

def to_lat_lng(json):
  return '{0}, {1}'.format(json["lat"], json['lng'])

def get_cities_df(cities):
    points = []
    north_easts = []
    south_wests = []
    
    for target_city in cities: 
        # Build the endpoint URL
        target_url = ('https://maps.googleapis.com/maps/api/geocode/json?address={0}&key={1}').format(target_city, gkey)
        # Run a request to endpoint and convert result to json
        response = requests.get(target_url).json()
        geometry = response["results"][0]["geometry"]

        # Extract latitude and longitude.
        points.append(to_lat_lng(geometry["location"]))
        north_easts.append(to_lat_lng(geometry["bounds"]["northeast"]))
        south_wests.append(to_lat_lng(geometry["bounds"]["southwest"]))

    return pd.DataFrame({
        "City": cities,
        "Point": points,
        "Northeast": north_easts,
        "Southwest": south_wests,
    }) 

# cities = ["Palo Alto, California"]
cities = ["San Francisco, California", "Redwood City, California", "Berkeley, California", "Palo Alto, California", "Mountain View, California", "Sunnyvale, California", "Cupertino, California", "Santa Clara, California", "San Jose, California", "Fremont, California"]
# cities_df = get_cities_df(cities)
# cities_df.to_csv('cities.csv')

# %%
def get_response(url, params):
    response = requests.get(url, params=params).json()
    if response['status'] == 'OK':
        return response
    else:
        print('Not OK response: ' + response['status'])
        return None

# Returns DataFrame
def request_places(city, location, type, gkey):    
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # rankby:distance will result INVALID_REQUSET
    params = {
        "location": location,
        "radius": 10000, # hard-code distance
        "type": type,
        "key": gkey,
    }

    response = get_response(base_url, params)
    results= response['results']
    count = 1
    
    # If there is no page token, return result, otherwise concat result with next page.
    while (count < 3 and 'next_page_token' in response):
        count = count + 1
        token = response['next_page_token']
#         print(f'Getting next page: {count}, token: {token}')
        
        # Sleep a while so that token can be used.
        time.sleep(3)
        params = {
            "location": location,
            "radius": 10000, # hard-code distance
            "type": type,
            "key": gkey,
            "page_token": response['next_page_token'],
        }
        base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
        response = get_response(base_url, params)
        results.extend(response['results'])
    
    print(f'Total page count: {count}')
    return results

def to_data_frame(city, type, results):
    cities = []
    types = []
    place_ids = []
    names = []
    poi = []
    vicnities = []
    locations = []
    
    for result in results:
        # Skip locality place, e.g. Palo Alto.
        if ('locality' in result['types']):
            continue

        cities.append(city)
        types.append(type)
        place_ids.append(result['place_id'])
        names.append(result['name'])
        poi.append(result['types'])
        vicnities.append(result['vicinity'])
        locations.append(to_lat_lng(result['geometry']['location']))
    
    return pd.DataFrame({
        'City': cities,
        'Type': types,
        'Place ID': place_ids,
        'Name': names,
        'Point of interests': poi,
        'Address': vicnities,
        'LatLng': locations,
    })

def get_places_data_frame(city, location, type, gkey):
    print(f'Getting plcaes, city: "{city}", location: "{location}", type: "{type}"');
    results = request_places(city, location, type, gkey)
    return to_data_frame(city, type, results)

# %%
cities_df = pd.read_csv("cities.csv")
type = 'restaurant'

def get_all_places_data_frame(type, gkey):
    frames = [];
    for index, row in cities_df.iterrows():
        frames.append(get_places_data_frame(row['City'], row['Point'], type, gkey))
    return pd.concat(frames)

place_df = get_all_places_data_frame(type, gkey)
place_df.to_csv(type + '.csv')
place_df
# Out:
# Getting plcaes, city: San Francisco, California, location: 37.7749295, -122.4194155, type: restaurant
# Total page count: 3
# Getting plcaes, city: Redwood City, California, location: 37.48521520000001, -122.2363548, type: restaurant
# Total page count: 3
# Getting plcaes, city: Berkeley, California, location: 37.8715926, -122.272747, type: restaurant
# Total page count: 3
# Getting plcaes, city: Palo Alto, California, location: 37.4418834, -122.1430195, type: restaurant
# Total page count: 3
# Getting plcaes, city: Mountain View, California, location: 37.3860517, -122.0838511, type: restaurant
# Total page count: 3
# Getting plcaes, city: Sunnyvale, California, location: 37.36883, -122.0363496, type: restaurant
# Total page count: 3
# Getting plcaes, city: Cupertino, California, location: 37.3229978, -122.0321823, type: restaurant
# Total page count: 3
# Getting plcaes, city: Santa Clara, California, location: 37.3541079, -121.9552356, type: restaurant
# Total page count: 3
# Getting plcaes, city: San Jose, California, location: 37.3382082, -121.8863286, type: restaurant
# Total page count: 3
# Getting plcaes, city: Fremont, California, location: 37.5482697, -121.9885719, type: restaurant
# Total page count: 3
#                          City        Type                     Place ID  \
# 0   San Francisco, California  restaurant  ChIJ0SMraI-AhYAREeJAvm2_yGM
# 1   San Francisco, California  restaurant  ChIJN2S4EI2AhYAR9J4Qeh1U8Aw
# 2   San Francisco, California  restaurant  ChIJURDKN2eAhYARN0AMzUEaiKo
# 3   San Francisco, California  restaurant  ChIJ18LA7PSAhYARZCNy_dme7v8
# 4   San Francisco, California  restaurant  ChIJIbtvA4qAhYARdnwerOi-f4I
# 5   San Francisco, California  restaurant  ChIJO8CPF2GAhYARBKYOHZoWGCo
# 6   San Francisco, California  restaurant  ChIJzWMEoXuAhYARnGNx8NeVTpY
# 7   San Francisco, California  restaurant  ChIJP5PrLYSAhYARBcWhJXs55P4
# 8   San Francisco, California  restaurant  ChIJiZyN7IeAhYARnCn-G6GH73Q
# 9   San Francisco, California  restaurant  ChIJW52Si_OAhYAR-jAC1-iQh_c
# 10  San Francisco, California  restaurant  ChIJSToWqn2AhYAR1CuH2iGMvuo
# 11  San Francisco, California  restaurant  ChIJF-zbSmSAhYARvOafjdCRszQ
# 12  San Francisco, California  restaurant  ChIJZduCKJGAhYARueNvSMvqsUI
# 13  San Francisco, California  restaurant  ChIJNRipBPGAhYAR1qLFGG_Tby4
# 14  San Francisco, California  restaurant  ChIJ6zMe3oWAhYARaZ33Z1BAMRo
# 15  San Francisco, California  restaurant  ChIJf-NCNpeHhYARLeneHNw3WWs
# 16  San Francisco, California  restaurant  ChIJn5G9Fzp-j4ARRs66QTw4XAY
# 17  San Francisco, California  restaurant  ChIJNy8VmmGAhYARQF84_9twEc4
# 18  San Francisco, California  restaurant  ChIJl7zcHY-AhYAR4rDx9C6-N4s
# 19  San Francisco, California  restaurant  ChIJk2EFyIqAhYARXlKs2zO34Fg
# 20  San Francisco, California  restaurant  ChIJ0SMraI-AhYAREeJAvm2_yGM
# 21  San Francisco, California  restaurant  ChIJN2S4EI2AhYAR9J4Qeh1U8Aw
# 22  San Francisco, California  restaurant  ChIJURDKN2eAhYARN0AMzUEaiKo
#
#                                Name  \
# 0                      Hotel Fusion
# 1            Fairmont San Francisco
# 2         La Mar Cebicheria Peruana
# 3                   Comstock Saloon
# 4                             Credo
# 5       Hornblower Cruises & Events
# 6     Local Kitchen & Wine Merchant
# 7                        54 Mint SF
# 8           The Grove - Yerba Buena
# 9                 The Stinking Rose
# 10                             Benu
# 11             Boulevard Restaurant
# 12                         Lers Ros
# 13                      Park Tavern
# 14   Westfield San Francisco Centre
# 15                       Outerlands
# 16         Southern Pacific Brewing
# 17                         Perbacco
# 18                      Daily Grill
# 19                 Taverna Aventine
# 20                     Hotel Fusion
# 21           Fairmont San Francisco
# 22        La Mar Cebicheria Peruana
# 23                  Comstock Saloon
# 24                            Credo
# 25      Hornblower Cruises & Events
# 26    Local Kitchen & Wine Merchant
# 27                       54 Mint SF
# 28          The Grove - Yerba Buena
# 29                The Stinking Rose
# ..                              ...
# 30     Mayflower Seafood Restaurant
# 31             Little Caesars Pizza
# 32             Little Caesars Pizza
# 33                    Pizza & Curry
# 34            Mountain Mike's Pizza
# 35                Chuck E. Cheese's
# 36         Claim Jumper Restaurants
# 37  Olive Garden Italian Restaurant
# 38                 Saravanaa Bhavan
# 39                Round Table Pizza
# 40                  The Saddle Rack
# 41          Sweet Tomatoes- Fremont
# 42        Campo di Bocce of Fremont
# 43           Chaat Bhavan - Fremont
# 44               Chandni Restaurant
# 45                     Satomi Sushi
# 46                  Texas Roadhouse
# 47                     P.F. Chang's
# 48               DeAfghanan Cuisine
# 49      BJ's Restaurant & Brewhouse
# 50     Mayflower Seafood Restaurant
# 51             Little Caesars Pizza
# 52             Little Caesars Pizza
# 53                    Pizza & Curry
# 54            Mountain Mike's Pizza
# 55                Chuck E. Cheese's
# 56         Claim Jumper Restaurants
# 57  Olive Garden Italian Restaurant
# 58                 Saravanaa Bhavan
# 59                Round Table Pizza
#
#                                    Point of interests  \
# 0   [night_club, lodging, restaurant, food, point_...
# 1   [lodging, restaurant, food, point_of_interest,...
# 2   [restaurant, food, point_of_interest, establis...
# 3   [bar, restaurant, food, point_of_interest, est...
# 4   [bar, restaurant, food, point_of_interest, est...
# 5   [travel_agency, restaurant, food, point_of_int...
# 6   [liquor_store, night_club, bar, store, restaur...
# 7   [bar, restaurant, food, point_of_interest, est...
# 8   [restaurant, food, point_of_interest, establis...
# 9   [bar, restaurant, food, point_of_interest, est...
# 10  [restaurant, food, point_of_interest, establis...
# 11  [bar, restaurant, food, point_of_interest, est...
# 12  [meal_delivery, restaurant, food, point_of_int...
# 13  [bar, restaurant, food, point_of_interest, est...
# 14  [shopping_mall, shoe_store, movie_theater, dep...
# 15  [bar, restaurant, food, point_of_interest, est...
# 16  [bar, restaurant, food, point_of_interest, est...
# 17  [bar, restaurant, food, point_of_interest, est...
# 18  [bar, restaurant, food, point_of_interest, est...
# 19  [bar, restaurant, food, point_of_interest, est...
# 20  [night_club, lodging, restaurant, food, point_...
# 21  [lodging, restaurant, food, point_of_interest,...
# 22  [restaurant, food, point_of_interest, establis...
# 23  [bar, restaurant, food, point_of_interest, est...
# 24  [bar, restaurant, food, point_of_interest, est...
# 25  [travel_agency, restaurant, food, point_of_int...
# 26  [liquor_store, night_club, bar, store, restaur...
# 27  [bar, restaurant, food, point_of_interest, est...
# 28  [restaurant, food, point_of_interest, establis...
# 29  [bar, restaurant, food, point_of_interest, est...
# ..                                                ...
# 30  [restaurant, food, point_of_interest, establis...
# 31  [meal_takeaway, restaurant, food, point_of_int...
# 32  [meal_takeaway, restaurant, food, point_of_int...
# 33  [restaurant, food, point_of_interest, establis...
# 34  [meal_delivery, meal_takeaway, restaurant, foo...
# 35  [restaurant, food, point_of_interest, establis...
# 36  [restaurant, bar, food, point_of_interest, est...
# 37  [bar, meal_takeaway, restaurant, food, point_o...
# 38  [restaurant, food, point_of_interest, establis...
# 39  [meal_delivery, meal_takeaway, restaurant, foo...
# 40  [night_club, restaurant, food, point_of_intere...
# 41  [restaurant, food, point_of_interest, establis...
# 42  [bar, restaurant, food, point_of_interest, est...
# 43  [restaurant, food, point_of_interest, establis...
# 44  [restaurant, food, point_of_interest, establis...
# 45  [restaurant, food, point_of_interest, establis...
# 46  [bar, restaurant, food, point_of_interest, est...
# 47  [restaurant, food, point_of_interest, establis...
# 48  [restaurant, food, point_of_interest, establis...
# 49  [restaurant, bar, meal_takeaway, food, point_o...
# 50  [restaurant, food, point_of_interest, establis...
# 51  [meal_takeaway, restaurant, food, point_of_int...
# 52  [meal_takeaway, restaurant, food, point_of_int...
# 53  [restaurant, food, point_of_interest, establis...
# 54  [meal_delivery, meal_takeaway, restaurant, foo...
# 55  [restaurant, food, point_of_interest, establis...
# 56  [restaurant, bar, food, point_of_interest, est...
# 57  [bar, meal_takeaway, restaurant, food, point_o...
# 58  [restaurant, food, point_of_interest, establis...
# 59  [meal_delivery, meal_takeaway, restaurant, foo...
#
#                                        Address  \
# 0              140 Ellis Street, San Francisco
# 1              950 Mason Street, San Francisco
# 2    pier 1 1/2 The Embarcadero, San Francisco
# 3           155 Columbus Avenue, San Francisco
# 4               360 Pine Street, San Francisco
# 5    Pier 3, Hornblower Landing, San Francisco
# 6             330 1st Street #1, San Francisco
# 7                 16 Mint Plaza, San Francisco
# 8            690 Mission Street, San Francisco
# 9           325 Columbus Avenue, San Francisco
# 10          22 Hawthorne Street, San Francisco
# 11             1 Mission Street, San Francisco
# 12            730 Larkin Street, San Francisco
# 13         1652 Stockton Street, San Francisco
# 14            865 Market Street, San Francisco
# 15            4001 Judah Street, San Francisco
# 16             620 Treat Avenue, San Francisco
# 17        230 California Street, San Francisco
# 18             347 Geary Street, San Francisco
# 19  2929, 582 Washington Street, San Francisco
# 20             140 Ellis Street, San Francisco
# 21             950 Mason Street, San Francisco
# 22   pier 1 1/2 The Embarcadero, San Francisco
# 23          155 Columbus Avenue, San Francisco
# 24              360 Pine Street, San Francisco
# 25   Pier 3, Hornblower Landing, San Francisco
# 26            330 1st Street #1, San Francisco
# 27                16 Mint Plaza, San Francisco
# 28           690 Mission Street, San Francisco
# 29          325 Columbus Avenue, San Francisco
# ..                                         ...
# 30       34348 Alvarado-Niles Road, Union City
# 31               4376 Thornton Avenue, Fremont
# 32            39490 Fremont Boulevard, Fremont
# 33                  42136 Blacow Road, Fremont
